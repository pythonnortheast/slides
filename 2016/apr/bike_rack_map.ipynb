# %% [markdown]
# # Using folium to map the bike racks in Newcastle

# %% [markdown]
# <img src="changing_stuff.jpg",width=400>

# %% [markdown]
# DATA: https://www.newcastle.gov.uk/your-council-and-democracy/open-data-and-access-information/open-data/data-sets/cycle-parking-urban-core
#
# THIS NOTEBOOK: https://github.com/pythonnortheast/slides/tree/master/2016/apr

# %%
# !ls
# Out:
# bike_rack_map.ipynb     ncle_cycle_parking.kml
# changing_stuff.jpg      ncle_cycle_parking1.csv

# %%
# !cat ncle_cycle_parking1.csv
# Out:
# ﻿WKT,Main_Attra,Type_Offic,Type_Infor,Covered,Number_Spa,Condition
# "POINT (424879.983 564728.767 0)",Retail,Sheffield,N/A,No,8,Good
# "POINT (424876.083 564744.673 0)",Retail,Sheffield,N/A,No,6,Good
# "POINT (425319.132 564087.931 0)",Employment,Sheffield,N/A,No,8,Good
# "POINT (425117.911 564154.672 0)",Employment,Sheffield,N/A,No,20,Good
# "POINT (424933.106 564487.726 0)",Retail,Sheffield,N/A,No,16,Good
# "POINT (424900.252 564341.091 0)",Retail,Sheffield,N/A,No,6,Good
# "POINT (424884.554 564375.368 0)",Retail,Sheffield,N/A,No,8,Good
# "POINT (424830.164 564132.905 0)",OpenSpace,Sheffield,N/A,No,12,Good
# "POINT (424409.489 563802.258 0)",OpenSpace,Sheffield,N/A,No,16,Good
# "POINT (424332.545 563953.14485674375 0)",Employment,Sheffield,N/A,No,12,Good
# "POINT (424255.24 563853.912 0)",Employment,Sheffield,N/A,No,8,Good
# "POINT (424874.414 564456.469 0)",Retail,Sheffield,N/A,No,6,Good
# "POINT (424830.758 564454.984 0)",Retail,Sheffield,N/A,No,10,Good
# "POINT (424830.164 564296.84 0)",Retail,Sheffield,N/A,No,6,Good
# "POINT (424795.12 564281.991 0)",Retail,Sheffield,N/A,Yes,6,Good
# "POINT (424937.544 564046.404 0)",Employment,Sheffield,N/A,No,4,Good
# "POINT (424719.686 564382.371 0)",Retail,Sheffield,N/A,No,10,Good
# "POINT (424692.91257103928 564314.23826542834 0)",Retail,Sheffield,N/A,No,14,Good
# "POINT (424697.404 564467.228 0)",Retail,Sheffield,N/A,Yes,8,Good
# "POINT (424579.264 564434.026 0)",Leisure,Sheffield,N/A,No,2,Good
# "POINT (424578.48872952419 564345.56986546458 0)",Leisure,Sheffield,N/A,No,6,Good
# "POINT (424610.989 564258.232 0)",Leisure,Sheffield,N/A,No,6,Good
# "POINT (424623.463 564207.151 0)",Retail,Sheffield,N/A,No,4,Good
# "POINT (424719.092 564167.355 0)",Retail,Sheffield,N/A,No,8,Good
# "POINT (424587.30624841212 564013.75 0)",Employment,Sheffield,N/A,No,4,Good
# "POINT (424293.17023571249 564004.46362738137 0)",Employment,Sheffield,N/A,No,16,Good
# "POINT (424279.669 564101.998 0)",Employment,Sheffield,N/A,Yes,4,Good
# "POINT (425093.398 564525.299 0)",Education,Sheffield,N/A,No,8,Good
# "POINT (425146.493 564513.595 0)",Employment,Sheffield,N/A,No,20,Good
# "POINT (425060.855 564535.861 0)",Education,Sheffield,N/A,Yes,14,Good
# "POINT (425050.293 564515.593 0)",Education,Sheffield,N/A,No,4,Good
# "POINT (424945.393 564462.111 0)",Retail,Sheffield,N/A,No,8,Good
# "POINT (424852.14 564650.03 0)",Retail,N/A,Railings,No,N/A,Good
# "POINT (424919.546 564739.887 0)",Retail,Sheffield,N/A,No,14,Good
# "POINT (424506.59055542952 564074.45639294235 0)",Retail,Sheffield,N/A,No,4,Good
# "POINT (424317.505 563803.176 0)",Employment,Sheffield,N/A,No,12,Good
# "POINT (424283.16587579373 563904.88818770635 0)",Employment,Sheffield,N/A,No,4,Good
# "POINT (424934.108 564595.903 0)",Retail,Sheffield,N/A,Yes,8,Good
# "POINT (424820.759 564864.648 0)",Retail,Sheffield,N/A,No,10,Good
# "POINT (424824.838 564852.994 0)",Retail,Sheffield,N/A,No,18,Good
# "POINT (424801.894 564865.259 0)",Retail,Sheffield,N/A,No,16,Good
# "POINT (424988.364 564543.98 0)",Leisure,Sheffield,N/A,No,6,Good
# "POINT (425006.322 564582.459 0)",Leisure,Sheffield,N/A,No,16,Good
# "POINT (424349.935 564686.518 0)",Leisure,Sheffield,N/A,Yes,8,Good
# "POINT (424193.095 564620.948 0)",Leisure,Sheffield,N/A,Yes,4,Good
# "POINT (424169.152 564605.553 0)",Leisure,Sheffield,N/A,No,4,Good
# "POINT (424465.026 564490.965 0)",Leisure,Sheffield,N/A,Yes,10,Good
# "POINT (424458.036 564468.771 0)",Leisure,Sheffield,N/A,No,8,Good
# "POINT (424467.302 564440.201 0)",Leisure,Sheffield,N/A,No,14,Good
# "POINT (424386.351 564316.515 0)",Employment,Sheffield,N/A,No,4,Good
# "POINT (424309.392 564386.645 0)",Employment,Sheffield,N/A,No,14,Good
# "POINT (426510.51 564083.062 0)",Leisure,Sheffield,N/A,No,20,Good
# "POINT (426452.357 564206.197 0)",Leisure,Sheffield,N/A,Yes,10,Good
# "POINT (426397.627 564206.197 0)",Leisure,Sheffield,N/A,Yes,18,Good
# "POINT (426308.695 564630.345 0)",Leisure,Sheffield,N/A,Yes,22,Good
# "POINT (426240.939 564604.671 0)",Leisure,Sheffield,N/A,Yes,4,Good
# "POINT (426188.977 564630.345 0)",Leisure,Sheffield,N/A,No,4,Good
# "POINT (426188.977 564534.573 0)",Leisure,Sheffield,N/A,No,16,Good
# "POINT (425802.457 564821.901 0)",OpenSpace,Sheffield,N/A,No,12,Good
# "POINT (425799.267 564728.215 0)",Leisure,Sheffield,N/A,No,8,Good
# "POINT (425864.023 564596.135 0)",Other,Sheffield,N/A,No,10,Good
# "POINT (425911.91 564527.725 0)",Leisure,Sheffield,N/A,No,4,Good
# "POINT (426004.271 564298.55 0)",Other,Sheffield,N/A,No,4,Good
# "POINT (425946.119 564421.695 0)",Retail,Sheffield,N/A,No,2,Good
# "POINT (425857.951 564313.569 0)",Other,Sheffield,N/A,No,4,Good
# "POINT (425679.317 564370.39 0)",Other,Sheffield,N/A,Yes,32,Good
# "POINT (425710.104 564377.228 0)",Other,Sheffield,N/A,No,6,Good
# "POINT (425508.165 563975.366 0)",Leisure,Sheffield,N/A,No,10,Good
# "POINT (425696.417 564035.176 0)",Leisure,Sheffield,N/A,No,8,Good
# "POINT (425882.66 564155.278 0)",Employment,Sheffield,N/A,No,18,Good
# "POINT (425344.106 564042.014 0)",Employment,Sheffield,N/A,No,12,Good
# "POINT (425223.241 563868.036 0)",Leisure,Sheffield,N/A,No,10,Good
# "POINT (425053.36 563693.114 0)",Leisure,Sheffield,N/A,No,6,Good
# "POINT (424629.454 563360.731 0)",Leisure,Sheffield,N/A,No,2,Good
# "POINT (424482.745 563231.009 0)",Leisure,Sheffield,N/A,No,2,Damaged
# "POINT (424411.707 563172.325 0)",Leisure,Sheffield,N/A,No,2,Good
# "POINT (424207.858 563032.565 0)",Leisure,Sheffield,N/A,No,4,Damaged
# "POINT (424222.167 563039.801 0)",Leisure,Sheffield,N/A,No,4,Damaged
# "POINT (424105.871 562985.066 0)",Leisure,Sheffield,N/A,No,4,Good
# "POINT
0)",Retail,Sheffield,N/A,No,4,Good
# "POINT (424808.187 564456.766 0)",Retail,Sheffield,N/A,No,6,Good
# "POINT (424377.67147777497 564088.87048412487 0)",OpenSpace,Sheffield,N/A,No,8,Good
# "POINT (424452.8075476251 564109.38764008123 0)",Employment,Sheffield,N/A,No,6,Good
# "POINT (424547.9594950641 564128.92955542949 0)",Retail,Sheffield,N/A,No,4,Good
# "POINT (424597.922 564178.64 0)",Retail,Sheffield,N/A,No,4,Good
# "POINT (424454.068 564238.218 0)",Other,Sheffield,N/A,Yes,24,Good
# "POINT (424926.733 563994.67 0)",OpenSpace,Sheffield,N/A,No,6,Good
# "POINT (425118.059 563795.684 0)",OpenSpace,N/A,Railings,No,N/A,Good
# "POINT (425208.961 563796.614 0)",OpenSpace,Sheffield,N/A,No,10,Good
# "POINT (424783.113 563732.91 0)",Employment,Sheffield,N/A,No,12,Good
# "POINT (424756.324 563929.116 0)",Transport_Interchange,Sheffield,N/A,No,6,Good
# "POINT (424833.41815148079 563966.64169703843 0)",Retail,Sheffield,N/A,No,10,Good
# "POINT (424294.732 563575.737 0)",Employment,Sheffield,N/A,No,6,Good
# "POINT (424272.594 563590.493 0)",Employment,Sheffield,N/A,No,8,Good
# "POINT (423777.769 563329.072 0)",Retail,Sheffield,N/A,No,10,Good
# "POINT (423720.035 563272.094 0)",Employment,Sheffield,N/A,No,10,Good
# "POINT (424146.131 563937.094 0)",Education,Sheffield,N/A,No,7,Good
# "POINT (426515.094 564087.221 0)",Leisure,Ground Slot,N/A,Yes,20,Good
# "POINT (424971.5890174649 564610.68593156012 0)",Retail,Sheffield,N/A,,,
# "POINT (424959.16257256531 564605.79683848482 0)",Retail,Sheffield,N/A,,,
# "POINT (424191.47795848863 563698.18088324531 0)",Retail,Sheffield,N/A,,,
# "POINT (424199.56 563741.76 0)",Retail,Sheffield,N/A,,,
# "POINT (424878.911 565135.741 0)",Education,Sheffield,N/A,No,20,Good
# "POINT (424947.61188271095 564455.76414860866 0)",Retail,,Railings,,,
# "POINT (424875.60976316425 564734.09166954551 0)",Employment,,Railings,,,

# %%
# !cat ncle_cycle_parking.kml
# Out:
# <?xml version="1.0" encoding="utf-8" ?>
# <kml xmlns="http://www.opengis.net/kml/2.2">
# <Document id="root_doc">
# <Schema name="Ncle_Cycle_Parking" id="Ncle_Cycle_Parking">
# 	<SimpleField name="Main_Attra" type="string"></SimpleField>
# 	<SimpleField name="Type_Offic" type="string"></SimpleField>
# 	<SimpleField name="Type_Infor" type="string"></SimpleField>
# 	<SimpleField name="Covered" type="string"></SimpleField>
# 	<SimpleField name="Number_Spa" type="string"></SimpleField>
# 	<SimpleField name="Condition" type="string"></SimpleField>
# </Schema>
# <Folder><name>Ncle_Cycle_Parking</name>
#   <Placemark>
# 	<ExtendedData><SchemaData schemaUrl="#Ncle_Cycle_Parking">
# 		<SimpleData name="Main_Attra">Retail</SimpleData>
# 		<SimpleData name="Type_Offic">Sheffield</SimpleData>
# 		<SimpleData name="Type_Infor">N/A</SimpleData>
# 		<SimpleData name="Covered">No</SimpleData>
# 		<SimpleData name="Number_Spa">8</SimpleData>
# 		<SimpleData name="Condition">Good</SimpleData>
# 	</SchemaData></ExtendedData>
#       <Point><altitudeMode>relativeToGround</altitudeMode><coordinates>-1.612828068198381,54.976552589676373,50.422893119975924</coordinates></Point>
#   </Placemark>
#   <Placemark>
# 	<ExtendedData><SchemaData schemaUrl="#Ncle_Cycle_Parking">
# 		<SimpleData name="Main_Attra">Retail</SimpleData>
# 		<SimpleData name="Type_Offic">Sheffield</SimpleData>
# 		<SimpleData name="Type_Infor">N/A</SimpleData>
# 		<SimpleData name="Covered">No</SimpleData>
# 		<SimpleData name="Number_Spa">6</SimpleData>
# 		<SimpleData name="Condition">Good</SimpleData>
# 	</SchemaData></ExtendedData>
#       <Point><altitudeMode>relativeToGround</altitudeMode><coordinates>-1.612887622949739,54.976695714527146,50.423002136871219</coordinates></Point>
#   </Placemark>
#   <Placemark>
# 	<ExtendedData><SchemaData schemaUrl="#Ncle_Cycle_Parking">
# 		<SimpleData name="Main_Attra">Employment</SimpleData>
# 		<SimpleData name="Type_Offic">Sheffield</SimpleData>
# 		<SimpleData name="Type_Infor">N/A</SimpleData>
# 		<SimpleData name="Covered">No</SimpleData>
# 		<SimpleData name="Number_Spa">8</SimpleData>
# 		<SimpleData name="Condition">Good</SimpleData>
# 	</SchemaData></ExtendedData>
#       <Point><altitudeMode>relativeToGround</altitudeMode><coordinates>-1.606023692195296,54.970772033205968,50.413524647243321</coordinates></Point>
#   </Placemark>
#   <Placemark>
# 	<ExtendedData><SchemaData schemaUrl="#Ncle_Cycle_Parking">
# 		<SimpleData name="Main_Attra">Employment</SimpleData>
# 		<SimpleData name="Type_Offic">Sheffield</SimpleData>
# 		<SimpleData name="Type_Infor">N/A</SimpleData>
# 		<SimpleData name="Covered">No</SimpleData>
# 		<SimpleData name="Number_Spa">20</SimpleData>
# 		<SimpleData name="Condition">Good</SimpleData>
# 	</SchemaData></ExtendedData>
#       <Point><altitudeMode>relativeToGround</altitudeMode><coordinates>-1.609161046205371,54.971381900949908,50.417242178693414</coordinates></Point>
#   </Placemark>
#   <Placemark>
# 	<ExtendedData><SchemaData schemaUrl="#Ncle_Cycle_Parking">
# 		<SimpleData name="Main_Attra">Retail</SimpleData>
# 		<SimpleData name="Type_Offic">Sheffield</SimpleData>
# 		<SimpleData name="Type_Infor">N/A</SimpleData>
# 		<SimpleData name="Covered">No</SimpleData>
# 		<SimpleData name="Number_Spa">16</SimpleData>
# 		<SimpleData name="Condition">Good</SimpleData>
# 	</SchemaData></ExtendedData>
#       <Point><altitudeMode>relativeToGround</altitudeMode><coordinates>-1.612019008737869,54.974383956219732,50.421345823444426</coordinates></Point>
#   </Placemark>
#   <Placemark>
# 	<ExtendedData><SchemaData schemaUrl="#Ncle_Cycle_Parking">
# 		<SimpleData name="Main_Attra">Retail</SimpleData>
# 		<SimpleData name="Type_Offic">Sheffield</SimpleData>
# 		<SimpleData name="Type_Infor">N/A</SimpleData>
# 		<SimpleData name="Covered">No</SimpleData>
# 		<SimpleData name="Number_Spa">6</SimpleData>
# 		<SimpleData name="Condition">Good</SimpleData>
# 	</SchemaData></ExtendedData>
#       <Point><altitudeMode>relativeToGround</altitudeMode><coordinates>-1.612544927847222,54.97306793079666,50.421552644111216</coordinates></Point>
#   </Placemark>
#   <Placemark>
# 	<ExtendedData><SchemaData schemaUrl="#Ncle_Cycle_Parking">
# 		<SimpleData name="Main_Attra">Retail</SimpleData>
# 		<SimpleData name="Type_Offic">Sheffield</SimpleData>
# 		<SimpleData name="Type_Infor">N/A</SimpleData>
# 		<SimpleData name="Covered">No</SimpleData>
# 		<SimpleData name="Number_Spa">8</SimpleData>
# 		<SimpleData name="Condition">Good</SimpleData>
# 	</SchemaData></ExtendedData>
#       <Point><altitudeMode>relativeToGround</altitudeMode><coordinates>-1.612787191318938,54.973376723919053,50.421916367486119</coordinates></Point>
#   </Placemark>
#   <Placemark>
# 	<ExtendedData><SchemaData schemaUrl="#Ncle_Cycle_Parking">
# 		<SimpleData name="Main_Attra">OpenSpace</SimpleData>
# 		<SimpleData name="Type_Offic">Sheffield</SimpleData>
# 		<SimpleData name="Type_Infor">N/A</SimpleData>
# 		<SimpleData name="Covered">No</SimpleData>
# 		<SimpleData name="Number_Spa">12</SimpleData>
# 		<SimpleData name="Condition">Good</SimpleData>
# 	</SchemaData></ExtendedData>
#       <Point><altitudeMode>relativeToGround</altitudeMode><coordinates>-1.613657746105847,54.9712006535661,50.422258720733225</coordinates></Point>
#   </Placemark>
#   <Placemark>
# 	<ExtendedData><SchemaData schemaUrl="#Ncle_Cycle_Parking">
# 		<SimpleData name="Main_Attra">OpenSpace</SimpleData>
# 		<SimpleData name="Type_Offic">Sheffield</SimpleData>
# 		<SimpleData name="Type_Infor">N/A</SimpleData>
# 		<SimpleData name="Covered">No</SimpleData>
# 		<SimpleData name="Number_Spa">16</SimpleData>
# 		<SimpleData name="Condition">Good</SimpleData>
# 	</SchemaData></ExtendedData>
#       <Point><altitudeMode>relativeToGround</altitudeMode><coordinates>-1
SimpleData>
# 	</SchemaData></ExtendedData>
#       <Point><altitudeMode>relativeToGround</altitudeMode><coordinates>-1.611795167615666,54.974096024911049,50.421009045094252</coordinates></Point>
#   </Placemark>
#   <Placemark>
# 	<ExtendedData><SchemaData schemaUrl="#Ncle_Cycle_Parking">
# 		<SimpleData name="Main_Attra">Employment</SimpleData>
# 		<SimpleData name="Type_Infor">Railings</SimpleData>
# 	</SchemaData></ExtendedData>
#       <Point><altitudeMode>relativeToGround</altitudeMode><coordinates>-1.612895930263708,54.976600654374288,50.422983680851758</coordinates></Point>
#   </Placemark>
# </Folder>
# </Document></kml>

# %%
import folium
from fastkml.kml import KML

# %%
# source: https://ocefpaf.github.io/python4oceanographers/blog/2014/05/05/folium/
# version 1 ...
def read_kml(fname='ncle_cycle_parking.kml'):
    kml = KML()
    kml.from_string(open(fname).read())
    points = dict()
    placemarks = []
    for feature in kml.features():
        print(feature)
        for placemark in feature.features():
            placemarks.append(placemark)
#             if placemark.styleUrl.startswith('#hf'):
#                 points.update({placemark.name:
#                             (placemark.geometry.y, placemark.geometry.x, )})
    #return points
    return placemarks

# %%
placemarks = read_kml()
# Out:
# <fastkml.kml.Document object at 0x105fade80>

# %%
print(placemarks[0].to_string(prettyprint=True))
# Out:
# <kml:Folder xmlns:kml="http://www.opengis.net/kml/2.2"><kml:name>Ncle_Cycle_Parking</kml:name><kml:visibility>1</kml:visibility><kml:Placemark><kml:visibility>1</kml:visibility><kml:ExtendedData><kml:SchemaData schemaUrl="#Ncle_Cycle_Parking"><kml:SimpleData name="Main_Attra">Retail</kml:SimpleData><kml:SimpleData name="Type_Offic">Sheffield</kml:SimpleData><kml:SimpleData name="Type_Infor">N/A</kml:SimpleData><kml:SimpleData name="Covered">No</kml:SimpleData><kml:SimpleData name="Number_Spa">8</kml:SimpleData><kml:SimpleData name="Condition">Good</kml:SimpleData></kml:SchemaData></kml:ExtendedData><kml:Point><kml:altitudeMode>relativeToGround</kml:altitudeMode><kml:coordinates>-1.612828,54.976553,50.422893</kml:coordinates></kml:Point></kml:Placemark><kml:Placemark><kml:visibility>1</kml:visibility><kml:ExtendedData><kml:SchemaData schemaUrl="#Ncle_Cycle_Parking"><kml:SimpleData name="Main_Attra">Retail</kml:SimpleData><kml:SimpleData name="Type_Offic">Sheffield</kml:SimpleData><kml:SimpleData name="Type_Infor">N/A</kml:SimpleData><kml:SimpleData name="Covered">No</kml:SimpleData><kml:SimpleData name="Number_Spa">6</kml:SimpleData><kml:SimpleData name="Condition">Good</kml:SimpleData></kml:SchemaData></kml:ExtendedData><kml:Point><kml:altitudeMode>relativeToGround</kml:altitudeMode><kml:coordinates>-1.612888,54.976696,50.423002</kml:coordinates></kml:Point></kml:Placemark><kml:Placemark><kml:visibility>1</kml:visibility><kml:ExtendedData><kml:SchemaData schemaUrl="#Ncle_Cycle_Parking"><kml:SimpleData name="Main_Attra">Employment</kml:SimpleData><kml:SimpleData name="Type_Offic">Sheffield</kml:SimpleData><kml:SimpleData name="Type_Infor">N/A</kml:SimpleData><kml:SimpleData name="Covered">No</kml:SimpleData><kml:SimpleData name="Number_Spa">8</kml:SimpleData><kml:SimpleData name="Condition">Good</kml:SimpleData></kml:SchemaData></kml:ExtendedData><kml:Point><kml:altitudeMode>relativeToGround</kml:altitudeMode><kml:coordinates>-1.606024,54.970772,50.413525</kml:coordinates></kml:Point></kml:Placemark><kml:Placemark><kml:visibility>1</kml:visibility><kml:ExtendedData><kml:SchemaData schemaUrl="#Ncle_Cycle_Parking"><kml:SimpleData name="Main_Attra">Employment</kml:SimpleData><kml:SimpleData name="Type_Offic">Sheffield</kml:SimpleData><kml:SimpleData name="Type_Infor">N/A</kml:SimpleData><kml:SimpleData name="Covered">No</kml:SimpleData><kml:SimpleData name="Number_Spa">20</kml:SimpleData><kml:SimpleData name="Condition">Good</kml:SimpleData></kml:SchemaData></kml:ExtendedData><kml:Point><kml:altitudeMode>relativeToGround</kml:altitudeMode><kml:coordinates>-1.609161,54.971382,50.417242</kml:coordinates></kml:Point></kml:Placemark><kml:Placemark><kml:visibility>1</kml:visibility><kml:ExtendedData><kml:SchemaData schemaUrl="#Ncle_Cycle_Parking"><kml:SimpleData name="Main_Attra">Retail</kml:SimpleData><kml:SimpleData name="Type_Offic">Sheffield</kml:SimpleData><kml:SimpleData name="Type_Infor">N/A</kml:SimpleData><kml:SimpleData name="Covered">No</kml:SimpleData><kml:SimpleData name="Number_Spa">16</kml:SimpleData><kml:SimpleData name="Condition">Good</kml:SimpleData></kml:SchemaData></kml:ExtendedData><kml:Point><kml:altitudeMode>relativeToGround</kml:altitudeMode><kml:coordinates>-1.612019,54.974384,50.421346</kml:coordinates></kml:Point></kml:Placemark><kml:Placemark><kml:visibility>1</kml:visibility><kml:ExtendedData><kml:SchemaData schemaUrl="#Ncle_Cycle_Parking"><kml:SimpleData name="Main_Attra">Retail</kml:SimpleData><kml:SimpleData name="Type_Offic">Sheffield</kml:SimpleData><kml:SimpleData name="Type_Infor">N/A</kml:SimpleData><kml:SimpleData name="Covered">No</kml:SimpleData><kml:SimpleData name="Number_Spa">6</kml:SimpleData><kml:SimpleData name="Condition">Good</kml:SimpleData></kml:SchemaData></kml:ExtendedData><kml:Point><kml:altitudeMode>relativeToGround</kml:altitudeMode><kml:coordinates>-1.612545,54.973068,50.421553</kml:coordinates></kml:Point></kml:Placemark><kml:Placemark><kml:visibility>1</kml:visibility><kml:Exte ...

# %%
placemarks_list = list(placemarks[0].features())

for pm in placemarks_list:
    print(pm)
# Out:
# <fastkml.kml.Placemark object at 0x105fadf60>
# <fastkml.kml.Placemark object at 0x105f4b0b8>
# <fastkml.kml.Placemark object at 0x105f4b1d0>
# <fastkml.kml.Placemark object at 0x105f4b2e8>
# <fastkml.kml.Placemark object at 0x105f4b400>
# <fastkml.kml.Placemark object at 0x105f4b518>
# <fastkml.kml.Placemark object at 0x105f4b630>
# <fastkml.kml.Placemark object at 0x105f4b748>
# <fastkml.kml.Placemark object at 0x105f4b860>
# <fastkml.kml.Placemark object at 0x105f52860>
# <fastkml.kml.Placemark object at 0x105f4b9e8>
# <fastkml.kml.Placemark object at 0x105f4bb00>
# <fastkml.kml.Placemark object at 0x105f4bc18>
# <fastkml.kml.Placemark object at 0x105f4bd30>
# <fastkml.kml.Placemark object at 0x105f4be48>
# <fastkml.kml.Placemark object at 0x105f4bf60>
# <fastkml.kml.Placemark object at 0x105fec0f0>
# <fastkml.kml.Placemark object at 0x105fec208>
# <fastkml.kml.Placemark object at 0x105fec320>
# <fastkml.kml.Placemark object at 0x105fec438>
# <fastkml.kml.Placemark object at 0x105fec550>
# <fastkml.kml.Placemark object at 0x105fec668>
# <fastkml.kml.Placemark object at 0x105fec780>
# <fastkml.kml.Placemark object at 0x105fec898>
# <fastkml.kml.Placemark object at 0x105fec9b0>
# <fastkml.kml.Placemark object at 0x105fecac8>
# <fastkml.kml.Placemark object at 0x105fecbe0>
# <fastkml.kml.Placemark object at 0x105feccf8>
# <fastkml.kml.Placemark object at 0x105fece10>
# <fastkml.kml.Placemark object at 0x105fecf28>
# <fastkml.kml.Placemark object at 0x105ff1048>
# <fastkml.kml.Placemark object at 0x105ff1160>
# <fastkml.kml.Placemark object at 0x105ff1278>
# <fastkml.kml.Placemark object at 0x105ff1390>
# <fastkml.kml.Placemark object at 0x105ff14a8>
# <fastkml.kml.Placemark object at 0x105ff15c0>
# <fastkml.kml.Placemark object at 0x105ff16d8>
# <fastkml.kml.Placemark object at 0x105ff17f0>
# <fastkml.kml.Placemark object at 0x105ff1908>
# <fastkml.kml.Placemark object at 0x105ff1a20>
# <fastkml.kml.Placemark object at 0x105ff1b38>
# <fastkml.kml.Placemark object at 0x105ff1c50>
# <fastkml.kml.Placemark object at 0x105ff1d68>
# <fastkml.kml.Placemark object at 0x105ff1e80>
# <fastkml.kml.Placemark object at 0x105ff1f98>
# <fastkml.kml.Placemark object at 0x105ff6128>
# <fastkml.kml.Placemark object at 0x105ff6240>
# <fastkml.kml.Placemark object at 0x105ff6358>
# <fastkml.kml.Placemark object at 0x105ff6470>
# <fastkml.kml.Placemark object at 0x105ff6588>
# <fastkml.kml.Placemark object at 0x105ff66a0>
# <fastkml.kml.Placemark object at 0x105ff67b8>
# <fastkml.kml.Placemark object at 0x105ff68d0>
# <fastkml.kml.Placemark object at 0x105ff69e8>
# <fastkml.kml.Placemark object at 0x105ff6b00>
# <fastkml.kml.Placemark object at 0x105ff6c18>
# <fastkml.kml.Placemark object at 0x105ff6d30>
# <fastkml.kml.Placemark object at 0x105ff6e48>
# <fastkml.kml.Placemark object at 0x105ff6f60>
# <fastkml.kml.Placemark object at 0x105fc3080>
# <fastkml.kml.Placemark object at 0x105fc3198>
# <fastkml.kml.Placemark object at 0x105fc32b0>
# <fastkml.kml.Placemark object at 0x105fc33c8>
# <fastkml.kml.Placemark object at 0x105fc34e0>
# <fastkml.kml.Placemark object at 0x105fc35f8>
# <fastkml.kml.Placemark object at 0x105fc3710>
# <fastkml.kml.Placemark object at 0x105fc3828>
# <fastkml.kml.Placemark object at 0x105fc3940>
# <fastkml.kml.Placemark object at 0x105fc3a58>
# <fastkml.kml.Placemark object at 0x105fc3b70>
# <fastkml.kml.Placemark object at 0x105fc3c88>
# <fastkml.kml.Placemark object at 0x105fc3da0>
# <fastkml.kml.Placemark object at 0x105fc3eb8>
# <fastkml.kml.Placemark object at 0x105fc3fd0>
# <fastkml.kml.Placemark object at 0x105fc9128>
# <fastkml.kml.Placemark object at 0x105fc92b0>
# <fastkml.kml.Placemark object at 0x105fc93c8>
# <fastkml.kml.Placemark object at 0x105fc94e0>
# <fastkml.kml.Placemark object at 0x105fc95f8>
# <fastkml.kml.Placemark object at 0x105fc9710>
# <fastkml.kml.Placemark object at 0x105fc9828>
# <fastkml.kml.Placemark object at 0x105fc9940>
# <fastkml.kml.Placemark object at 0x105fc9a58>
# <fastkml.kml.Placemark object at 0x105fc9b70>
# <fastkml.kml.Placemark object at 0x105fc9c88>
# <fastkml.kml.Placemark object at 0x105fc9da0>
# <fastkml.kml.Placemark object at 0x105fc9eb8>
# <fastkml.kml.Placemark object at 0x105fc9fd0>
# <fastkml.kml.Placemark object at 0x105fce0b8>
# <fastkml.kml.Placemark object at 0x105fce1d0>
# <fastkml.kml.Placemark object at 0x105fce2e8>
# <fastkml.kml.Placemark object at 0x105fce400>
# <fastkml.kml.Placemark object at 0x105fce518>
# <fastkml.kml.Placemark object at 0x105fce630>
# <fastkml.kml.Placemark object at 0x105fce748>
# <fastkml.kml.Placemark object at 0x105fce860>
# <fastkml.kml.Placemark object at 0x105fce978>
# <fastkml.kml.Placemark object at 0x105fcea90>
# <fastkml.kml.Placemark object at 0x105fceba8>
# <fastkml.kml.Placemark object at 0x105fcecc0>
# <fastkml.kml.Placemark object at 0x105fcedd8>
# <fastkml.kml.Placemark object at 0x105fceef0>
# <fastkml.kml.Placemark object at 0x105fd1048>
# <fastkml.kml.Placemark object at 0x105fd1160>
# <fastkml.kml.Placemark object at 0x105fd1278>
# <fastkml.kml.Placemark object at 0x105fd1390>
# <fastkml.kml.Placemark object at 0x105fd14a8>
# <fastkml.kml.Placemark object at 0x105fd15c0>
# <fastkml.kml.Placemark object at 0x105fd16d8>
# <fastkml.kml.Placemark object at 0x105fd17f0>
# <fastkml.kml.Placemark object at 0x105fd1908>
# <fastkml.kml.Placemark object at 0x105fd1a20>
# <fastkml.kml.Placemark object at 0x105fd1b38>
# <fastkml.kml.Placemark object at 0x105fd1c50>
# <fastkml.kml.Placemark object at 0x105fd1d68>
# <fastkml.kml.Placemark object at 0x105fd1e80>
# <fastkml.kml.Placemark object at 0x105fd1f98>
# <fastkml.kml.Placemark object at 0x105fd7160>
# <fastkml.kml.Placemark object at 0x105fd7278>
# <fastkml.kml.Placemark object at 0x105fd7390>
# <fastkml.kml.Placemark object at 0x105fd74a8>
# <fastkml.kml.Placemark object at 0x105fd75c0>
# <fastkml.kml.Placemark object at 0x105fd76d8>
# <fastkml.kml.Placemark object at 0x105fd77f0>
# <fastkml.kml.Placemark object at 0x105fd7908>
# <fastkml.kml.Placemark object at 0x105fd7a20>
# <fastkml.kml.Placemark object at 0x105fd7b38>
# <fastkml.kml.Placemark object at 0x105fd7c50>
# <fastkml.kml.Placemark object at 0x105fd7d68>
# <fastkml.kml.Placemark object at 0x105fd7e80>
# <fastkml.kml.Placemark object at 0x105fd7f98>
# <fastkml.kml.Placemark object at 0x105fd3080>
# <fastkml.kml.Placemark object at 0x105fd3198>
# <fastkml.kml.Placemark object at 0x105fd32b0>
# <fastkml.kml.Placemark object at 0x105fd33c8>
# <fastkml.kml.Placemark object at 0x105fd34e0>
# <fastkml.kml.Placemark object at 0x105fd35f8>
# <fastkml.kml.Placemark object at 0x105fd3710>
# <fastkml.kml.Placemark object at 0x105fd3828>
# <fastkml.kml.Placemark object at 0x105fd3940>
# <fastkml.kml.Placemark object at 0x105fd3a58>
# <fastkml.kml.Placemark object at 0x105fd3b70>
# <fastkml.kml.Placemark object at 0x105fd3c88>
# <fastkml.kml.Placemark object at 0x105fd3da0>
# <fastkml.kml.Placemark object at 0x105fd3eb8>
# <fastkml.kml.Placemark object at 0x105fd3fd0>
# <fastkml.kml.Placemark object at 0x105fff128>

# %%
print(pm.geometry.x)
# Out:
# -1.612895930263708

# %%
for el in pm.extended_data.elements:
    print(el.data)
# Out:
# ({'value': 'Employment', 'name': 'Main_Attra'}, {'value': 'Railings', 'name': 'Type_Infor'})

# %%
len(pm.extended_data.elements)
# Out:
# 1

# %%
print(pm.to_string())
print(pm.geometry)
print(pm.geometry.y, pm.geometry.x)
# Out:
# <kml:Placemark xmlns:kml="http://www.opengis.net/kml/2.2"><kml:visibility>1</kml:visibility><kml:ExtendedData><kml:SchemaData schemaUrl="#Ncle_Cycle_Parking"><kml:SimpleData name="Main_Attra">Employment</kml:SimpleData><kml:SimpleData name="Type_Infor">Railings</kml:SimpleData></kml:SchemaData></kml:ExtendedData><kml:Point><kml:altitudeMode>relativeToGround</kml:altitudeMode><kml:coordinates>-1.612896,54.976601,50.422984</kml:coordinates></kml:Point></kml:Placemark>
# POINT (-1.612895930263708 54.97660065437429 50.42298368085176)
# 54.97660065437429 -1.612895930263708

# %%
map_osm = folium.Map(location=[pm.geometry.y, pm.geometry.x],
                    zoom_start=15)

# %%
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
folium.Marker([pm.geometry.y, pm.geometry.x], popup='Test point 1').add_to(map_osm)

# %%
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
for pm in placemarks_list:
    folium.Marker([pm.geometry.y, pm.geometry.x], popup='Test point 1').add_to(map_osm)

# %%
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
def get_details(p_marker):
    _str=""
    for d in p_marker.extended_data.elements[0].data:
        _str += " " + d['name'] + "=" + d['value']
    return _str

# %%
for i, pm in enumerate(placemarks_list):
    #folium.Marker([pm.geometry.y, pm.geometry.x], popup='Test point 1').add_to(map_osm)
    print(i)
    print(get_details(pm))
# Out:
# 0
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=8 Condition=Good
# 1
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=6 Condition=Good
# 2
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=8 Condition=Good
# 3
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=20 Condition=Good
# 4
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=16 Condition=Good
# 5
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=6 Condition=Good
# 6
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=8 Condition=Good
# 7
#  Main_Attra=OpenSpace Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=12 Condition=Good
# 8
#  Main_Attra=OpenSpace Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=16 Condition=Good
# 9
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=12 Condition=Good
# 10
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=8 Condition=Good
# 11
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=6 Condition=Good
# 12
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=10 Condition=Good
# 13
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=6 Condition=Good
# 14
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=Yes Number_Spa=6 Condition=Good
# 15
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Good
# 16
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=10 Condition=Good
# 17
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=14 Condition=Good
# 18
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=Yes Number_Spa=8 Condition=Good
# 19
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=2 Condition=Good
# 20
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=6 Condition=Good
# 21
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=6 Condition=Good
# 22
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Good
# 23
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=8 Condition=Good
# 24
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Good
# 25
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=16 Condition=Good
# 26
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=Yes Number_Spa=4 Condition=Good
# 27
#  Main_Attra=Education Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=8 Condition=Good
# 28
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=20 Condition=Good
# 29
#  Main_Attra=Education Type_Offic=Sheffield Type_Infor=N/A Covered=Yes Number_Spa=14 Condition=Good
# 30
#  Main_Attra=Education Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Good
# 31
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=8 Condition=Good
# 32
#  Main_Attra=Retail Type_Offic=N/A Type_Infor=Railings Covered=No Number_Spa=N/A Condition=Good
# 33
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=14 Condition=Good
# 34
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Good
# 35
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=12 Condition=Good
# 36
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Good
# 37
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=Yes Number_Spa=8 Condition=Good
# 38
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=10 Condition=Good
# 39
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=18 Condition=Good
# 40
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=16 Condition=Good
# 41
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=6 Condition=Good
# 42
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=16 Condition=Good
# 43
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=Yes Number_Spa=8 Condition=Good
# 44
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=Yes Number_Spa=4 Condition=Good
# 45
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Good
# 46
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=Yes Number_Spa=10 Condition=Good
# 47
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=8 Condition=Good
# 48
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=14 Condition=Good
# 49
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Good
# 50
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=14 Condition=Good
# 51
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=20 Condition=Good
# 52
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=Yes Number_Spa=10 Condition=Good
# 53
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=Yes Number_Spa=18 Condition=Good
# 54
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=Yes Number_Spa=22 Condition=Good
# 55
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=Yes Number_Spa=4 Condition=Good
# 56
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Good
# 57
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=16 Condition=Good
# 58
#  Main_Attra=OpenSpace Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=12 Condition=Good
# 59
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=8 Condition=Good
# 60
#  Main_Attra=Other Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=10 Condition=Good
# 61
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Good
# 62
#  Main_Attra=Other Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Good
# 63
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=2 Condition=Good
# 64
#  Main_Attra=Other Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Good
# 65
#  Main_Attra=Other Type_Offic=Sheffield Type_Infor=N/A Covered=Yes Number_Spa=32 Condition=Good
# 66
#  Main_Attra=Other Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=6 Condition=Good
# 67
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=10 Condition=Good
# 68
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=8 Condition=Good
# 69
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=18 Condition=Good
# 70
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=12 Condition=Good
# 71
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=10 Condition=Good
# 72
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=6 Condition=Good
# 73
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=2 Condition=Good
# 74
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=2 Condition=Damaged
# 75
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=2 Condition=Good
# 76
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Damaged
# 77
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Damaged
# 78
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Good
# 79
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Good
# 80
#  Main_Attra=Employment Type_Offic=Other Type_Infor=N/A Covered=Yes Number_Spa=10 Condition=Good
# 81
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=8 Condition=Good
# 82
#  Main_Attra=Education Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=12 Condition=Good
# 83
#  Main_Attra=Education Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=6 Condition=Good
# 84
#  Main_Attra=Transport_Interchange Type_Offic=Sheffield Type_Infor=N/A Covered=Yes Number_Spa=64 Condition=Good
# 85
#  Main_Attra=Transport_Interchange Type_Offic=Sheffield Type_Infor=N/A Covered=Yes Number_Spa=58 Condition=Good
# 86
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Good
# 87
#  Main_Attra=Education Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=10 Condition=Good
# 88
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=Yes Number_Spa=4 Condition=Good
# 89
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=12 Condition=Good
# 90
#  Main_Attra=Transport_Interchange Type_Offic=Ground Slot Type_Infor=N/A Covered=No Number_Spa=10 Condition=Good
# 91
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=12 Condition=Good
# 92
#  Main_Attra=Transport_Interchange Type_Offic=Sheffield Type_Infor=N/A Covered=Yes Number_Spa=10 Condition=Good
# 93
#  Main_Attra=Other Type_Offic=Sheffield Type_Infor=N/A Covered=Yes Number_Spa=18 Condition=Good
# 94
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=Yes Number_Spa=14 Condition=Damaged
# 95
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Good
# 96
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=10 Condition=Good
# 97
#  Main_Attra=Employment Type_Offic=N/A Type_Infor=Railings Covered=Yes Number_Spa=N/A Condition=Good
# 98
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Good
# 99
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Good
# 100
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=8 Condition=Good
# 101
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=12 Condition=Good
# 102
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=2 Condition=Good
# 103
#  Main_Attra=Leisure Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Good
# 104
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Good
# 105
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Good
# 106
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=12 Condition=Good
# 107
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=6 Condition=Good
# 108
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=Yes Number_Spa=20 Condition=Good
# 109
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=Yes Number_Spa=20 Condition=Good
# 110
#  Main_Attra=Employment Type_Offic=Hoop Type_Infor=N/A Covered=No Number_Spa=4 Condition=Damaged
# 111
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=Yes Number_Spa=16 Condition=Good
# 112
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Good
# 113
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=2 Condition=Good
# 114
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=12 Condition=Good
# 115
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=8 Condition=Good
# 116
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Good
# 117
#  Main_Attra=Transport_Interchange Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=6 Condition=Good
# 118
#  Main_Attra=Transport_Interchange Type_Offic=Sheffield Type_Infor=N/A Covered=Yes Number_Spa=10 Condition=Good
# 119
#  Main_Attra=OpenSpace Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Good
# 120
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=6 Condition=Good
# 121
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Good
# 122
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=6 Condition=Good
# 123
#  Main_Attra=OpenSpace Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=8 Condition=Good
# 124
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=6 Condition=Good
# 125
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Good
# 126
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=4 Condition=Good
# 127
#  Main_Attra=Other Type_Offic=Sheffield Type_Infor=N/A Covered=Yes Number_Spa=24 Condition=Good
# 128
#  Main_Attra=OpenSpace Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=6 Condition=Good
# 129
#  Main_Attra=OpenSpace Type_Offic=N/A Type_Infor=Railings Covered=No Number_Spa=N/A Condition=Good
# 130
#  Main_Attra=OpenSpace Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=10 Condition=Good
# 131
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=12 Condition=Good
# 132
#  Main_Attra=Transport_Interchange Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=6 Condition=Good
# 133
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=10 Condition=Good
# 134
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=6 Condition=Good
# 135
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=8 Condition=Good
# 136
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=10 Condition=Good
# 137
#  Main_Attra=Employment Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=10 Condition=Good
# 138
#  Main_Attra=Education Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=7 Condition=Good
# 139
#  Main_Attra=Leisure Type_Offic=Ground Slot Type_Infor=N/A Covered=Yes Number_Spa=20 Condition=Good
# 140
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A
# 141
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A
# 142
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A
# 143
#  Main_Attra=Retail Type_Offic=Sheffield Type_Infor=N/A
# 144
#  Main_Attra=Education Type_Offic=Sheffield Type_Infor=N/A Covered=No Number_Spa=20 Condition=Good
# 145
#  Main_Attra=Retail Type_Infor=Railings
# 146
#  Main_Attra=Employment Type_Infor=Railings

# %%
final_map_osm = folium.Map(location=[pm.geometry.y, pm.geometry.x],
                    zoom_start=15)
for i, pm in enumerate(placemarks_list):
    folium.Marker([pm.geometry.y, pm.geometry.x], popup=get_details(pm)).add_to(final_map_osm)

# %%
final_map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
